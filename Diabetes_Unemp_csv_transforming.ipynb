# %%
import pandas as pd
import datetime
import numpy as np
import os

# %%
diabetes_path = os.path.join("/Users/Kish/Desktop/GW_Bootcamp_Repository/test/GWARL201902DATA3/02-Homework/20-Tableau/Diabetes.csv")
diabetes = pd.read_csv(diabetes_path)
diabetes.head()
# Out:
#   metro_nonmetro                   county_name state_abbr      geoId     value
# 0   Metropolitan        Anchorage Municipality         AK  us-ak-020  0.078000
# 1   Metropolitan  Fairbanks North Star Borough         AK  us-ak-090  0.062001
# 2   Metropolitan     Matanuska-Susitna Borough         AK  us-ak-170  0.087000
# 3   Metropolitan                Autauga County         AL  us-al-001  0.111001
# 4   Metropolitan                Baldwin County         AL  us-al-003  0.107000

# %%
diabetes.count()
# Out:
# metro_nonmetro    3140
# county_name       3140
# state_abbr        3140
# geoId             3140
# value             3140
# dtype: int64

# %%
unemployment_path = os.path.join("/Users/Kish/Desktop/GW_Bootcamp_Repository/test/GWARL201902DATA3/02-Homework/20-Tableau/Unemployment.csv")
unemployment = pd.read_csv(unemployment_path)
unemployment.head()
# Out:
#   metro_nonmetro  year                                  county_name  \
# 0            NaN  2016                         Kusilvak Census Area
# 1            NaN  2016  Prince of Wales-Outer Ketchikan Census Area
# 2            NaN  2016            Skagway-Hoonah-Angoon Census Area
# 3            NaN  2016              Wrangell-Petersburg Census Area
# 4            NaN  2016                         Oglala Lakota County
#
#   state_abbr      geoId     value
# 0         AK  us-ak-158  0.212782
# 1         AK  us-ak-201  0.000000
# 2         AK  us-ak-232  0.000000
# 3         AK  us-ak-280  0.000000
# 4         SD  us-sd-102  0.099835

# %%
combined_frame = pd.concat([diabetes, unemployment])
# Out:
# /Users/Kish/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
combined_frame.head()
# Out:
#                     county_name      geoId metro_nonmetro state_abbr  \
# 0        Anchorage Municipality  us-ak-020   Metropolitan         AK
# 1  Fairbanks North Star Borough  us-ak-090   Metropolitan         AK
# 2     Matanuska-Susitna Borough  us-ak-170   Metropolitan         AK
# 3                Autauga County  us-al-001   Metropolitan         AL
# 4                Baldwin County  us-al-003   Metropolitan         AL
#
#       value  year
# 0  0.078000   NaN
# 1  0.062001   NaN
# 2  0.087000   NaN
# 3  0.111001   NaN
# 4  0.107000   NaN

# %%
combined_path = os.path.join("combined_dia_unemp.csv")
combined_frame.to_csv(combined_path, index = False)

# %%
combined_frame.head()
# Out:
#                     county_name      geoId metro_nonmetro state_abbr  \
# 0        Anchorage Municipality  us-ak-020   Metropolitan         AK
# 1  Fairbanks North Star Borough  us-ak-090   Metropolitan         AK
# 2     Matanuska-Susitna Borough  us-ak-170   Metropolitan         AK
# 3                Autauga County  us-al-001   Metropolitan         AL
# 4                Baldwin County  us-al-003   Metropolitan         AL
#
#       value  year
# 0  0.078000   NaN
# 1  0.062001   NaN
# 2  0.087000   NaN
# 3  0.111001   NaN
# 4  0.107000   NaN

# %%
combined_frame.tail()
# Out:
#              county_name      geoId   metro_nonmetro state_abbr     value  \
# 37685  Sweetwater County  us-wy-037  Nonmetropolitan         WY  0.042364
# 37686       Teton County  us-wy-039  Nonmetropolitan         WY  0.030248
# 37687       Uinta County  us-wy-041  Nonmetropolitan         WY  0.043668
# 37688    Washakie County  us-wy-043  Nonmetropolitan         WY  0.042385
# 37689      Weston County  us-wy-045  Nonmetropolitan         WY  0.035111
#
#          year
# 37685  2018.0
# 37686  2018.0
# 37687  2018.0
# 37688  2018.0
# 37689  2018.0
